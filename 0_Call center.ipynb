# %%
import simpy
import random 
import numpy as np

# %%
class CallCenter:
    def __init__(self, env, num_employees, support_time):
        self.env = env
        self.staff = simpy.Resource(env, num_employees)
        self.support_time = support_time

    def support(self, customer):
        random_time = max(1, np.random.normal(self.support_time, 4))
        yield self.env.timeout(random_time)
        print(f"Support finished for {customer} at {self.env.now:.2f}")

def customer(env, name, call_center):
    global customers_handled
    print(f"Customer {name} enters waiting queue at {env.now:.2f}")
    with call_center.staff.request() as request:
        yield request
        print(f"Customer {name} enters call at {env.now:.2f}")
        yield env.process(call_center.support(name))
        customers_handled += 1

def set_up(env, num_employees, support_time, customer_interval):
    call_center = CallCenter(env, num_employees, support_time)

    initial_customers = 6
    for i in range(1, initial_customers):
        env.process(customer(env, i, call_center))

    customers_name = initial_customers
    while True:
        yield env.timeout(random.randint(customer_interval - 1, customer_interval +1))
        customers_name += 1
        env.process(customer(env, customers_name, call_center))

# %%
# The variables of the system
NUM_EMPLOYEES = 2
AVG_SUPPORT_TIME = 5
CUSTOMER_INTERVAL = 2
SIM_TIME = 120

# %%
# Initialise
customers_handled = 0

# Create a simpy environment
env = simpy.Environment()

# Asign the simpy environment a process to run
env.process(set_up(env, NUM_EMPLOYEES, AVG_SUPPORT_TIME, CUSTOMER_INTERVAL))

# Run
env.run(until=SIM_TIME)

print(f"Customes handled: {customers_handled}")
# Out:
# Customer 1 enters waiting queue at 0.00
# Customer 2 enters waiting queue at 0.00
# Customer 3 enters waiting queue at 0.00
# Customer 4 enters waiting queue at 0.00
# Customer 5 enters waiting queue at 0.00
# Customer 1 enters call at 0.00
# Customer 2 enters call at 0.00
# Customer 7 enters waiting queue at 2.00
# Customer 8 enters waiting queue at 3.00
# Support finished for 2 at 4.36
# Customer 3 enters call at 4.36
# Customer 9 enters waiting queue at 6.00
# Customer 10 enters waiting queue at 9.00
# Customer 11 enters waiting queue at 10.00
# Customer 12 enters waiting queue at 11.00
# Support finished for 1 at 12.13
# Customer 4 enters call at 12.13
# Customer 13 enters waiting queue at 13.00
# Customer 14 enters waiting queue at 14.00
# Customer 15 enters waiting queue at 15.00
# Customer 16 enters waiting queue at 18.00
# Support finished for 4 at 19.78
# Customer 5 enters call at 19.78
# Customer 17 enters waiting queue at 21.00
# Support finished for 3 at 21.79
# Customer 7 enters call at 21.79
# Customer 18 enters waiting queue at 23.00
# Support finished for 5 at 25.22
# Customer 8 enters call at 25.22
# Customer 19 enters waiting queue at 26.00
# Customer 20 enters waiting queue at 27.00
# Customer 21 enters waiting queue at 28.00
# Customer 22 enters waiting queue at 29.00
# Customer 23 enters waiting queue at 30.00
# Customer 24 enters waiting queue at 32.00
# Support finished for 7 at 32.75
# Customer 9 enters call at 32.75
# Customer 25 enters waiting queue at 33.00
# Customer 26 enters waiting queue at 36.00
# Customer 27 enters waiting queue at 37.00
# Support finished for 8 at 38.18
# Customer 10 enters call at 38.18
# Customer 28 enters waiting queue at 40.00
# Support finished for 9 at 41.21
# Customer 11 enters call at 41.21
# Customer 29 enters waiting queue at 42.00
# Customer 30 enters waiting queue at 43.00
# Support finished for 10 at 44.15
# Customer 12 enters call at 44.15
# Customer 31 enters waiting queue at 45.00
# Customer 32 enters waiting queue at 47.00
# Customer 33 enters waiting queue at 48.00
# Customer 34 enters waiting queue at 49.00
# Support finished for 12 at 50.28
# Customer 13 enters call at 50.28
# Support finished for 11 at 51.43
# Customer 14 enters call at 51.43
# Customer 35 enters waiting queue at 52.00
# Support finished for 13 at 53.20
# Customer 15 enters call at 53.20
# Customer 36 enters waiting queue at 54.00
# Support finished for 15 at 54.20
# Customer 16 enters call at 54.20
# Support finished for 14 at 54.70
# Customer 17 enters call at 54.70
# Customer 37 enters waiting queue at 55.00
# Support finished for 16 at 56.29
# Customer 18 enters call at 56.29
# Support finished for 17 at 56.66
# Customer 19 enters call at 56.66
# Support finished for 18 at 57.29
# Customer 20 enters call at 57.29
# Customer 38 enters waiting queue at 58.00
# Customer 39 enters waiting queue at 59.00
# Support finished for 20 at 61.10
# Customer 21 enters call at 61.10
# Customer 40 enters waiting queue at 62.00
# Support finished for 19 at 62.80
# Customer 22 enters call at 62.80
# Customer 41 enters waiting queue at 63.00
# Customer 42 enters waiting queue at 64.00
# Customer 43 enters waiting queue at 66.00
# Support finished for 21 at 67.41
# Customer 23 enters call at 67.41
# Customer 44 enters waiting queue at 68.00
# Support finished for 22 at 69.99
# Customer 24 enters call at 69.99
# Customer 45 enters waiting queue at 71.00
# Support finished for 23 at 72.17
# Customer 25 enters call at 72.17
# Support finished for 24 at 72.71
# Customer 26 enters call at 72.71
# Customer 46 enters waiting queue at 74.00
# Support finished for 26 at 76.81
# Customer 27 enters call at 76.81
# Customer 47 enters waiting queue at 77.00
# Customer 48 enters waiting queue at 79.00
# Support finished for 25 at 79.45
# Customer 28 enters call at 79.45
# Support finished for 28 at 80.45
# Customer 29 enters call at 80.45
# Customer 49 enters waiting queue at 81.00
# Customer 50 enters waiting queue at 83.00
# Customer 51 enters waiting queue at 84.00
# Customer 52 enters waiting queue at 87.00
# Customer 53 enters waiting queue at 88.00
# Customer 54 enters waiting queue at 90.00
# Support finished for 27 at 90.44
# Customer 30 enters call at 90.44
# Customer 55 enters waiting queue at 91.00
# Customer 56 enters waiting queue at 93.00
# Customer 57 enters waiting queue at 94.00
# Customer 58 enters waiting queue at 95.00
# Support finished for 29 at 95.65
# Customer 31 enters call at 95.65
# Support finished for 30 at 96.76
# Customer 32 enters call at 96.76
# Customer 59 enters waiting queue at 98.00
# Customer 60 enters waiting queue at 100.00
# Customer 61 enters waiting queue at 101.00
# Support finished for 31 at 101.58
# Customer 33 enters call at 101.58
# Customer 62 enters waiting queue at 103.00
# Customer 63 enters waiting queue at 105.00
# Customer 64 enters waiting queue at 106.00
# Support finished for 32 at 107.94
# Customer 34 enters call at 107.94
# Support finished for 34 at 108.94
# Customer 35 enters call at 108.94
# Customer 65 enters waiting queue at 109.00
# Customer 66 enters waiting queue at 110.00
# Support finished for 33 at 110.78
# Customer 36 enters call at 110.78
# Customer 67 enters waiting queue at 112.00
# Support finished for 35 at 114.41
# Customer 37 enters call at 114.41
# Customer 68 enters waiting queue at 115.00
# Customer 69 enters waiting queue at 116.00
# Support finished for 37 at 118.05
# Customer 38 enters call at 118.05
# Customer 70 enters waiting queue at 119.00
# Customes handled: 95
