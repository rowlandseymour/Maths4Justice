# %%
import simpy
import random 
import numpy as np

# %%
class CallCenter:
    def __init__(self, env, num_employees, support_time):
        self.env = env
        self.staff = simpy.Resource(env, num_employees)
        self.support_time = support_time

    def support(self, customer):
        random_time = max(1, np.random.normal(self.support_time, 4))
        yield self.env.timeout(random_time)
        print(f"Support finished for {customer} at {self.env.now:.2f}")

def customer(env, name, call_center):
    global customers_handled
    print(f"Customer {name} enters waiting queue at {env.now:.2f}")
    with call_center.staff.request() as request:
        yield request
        print(f"Customer {name} enters call at {env.now:.2f}")
        yield env.process(call_center.support(name))
        customers_handled += 1

def set_up(env, num_employees, support_time, customer_interval):
    call_center = CallCenter(env, num_employees, support_time)

    initial_customers = 6
    for i in range(1, initial_customers):
        env.process(customer(env, i, call_center))

    customers_name = initial_customers
    while True:
        yield env.timeout(random.randint(customer_interval - 1, customer_interval +1))
        customers_name += 1
        env.process(customer(env, customers_name, call_center))

# %%
# The variables of the system
NUM_EMPLOYEES = 2
AVG_SUPPORT_TIME = 5
CUSTOMER_INTERVAL = 2
SIM_TIME = 120

# %%
# Initialise
customers_handled = 0

# Create a simpy environment
env = simpy.Environment()

# Asign the simpy environment a process to run
env.process(set_up(env, NUM_EMPLOYEES, AVG_SUPPORT_TIME, CUSTOMER_INTERVAL))

# Run
env.run(until=SIM_TIME)

print(f"Customes handled: {customers_handled}")
# Out:
# Customer 1 enters waiting queue at 0.00
# Customer 2 enters waiting queue at 0.00
# Customer 3 enters waiting queue at 0.00
# Customer 4 enters waiting queue at 0.00
# Customer 5 enters waiting queue at 0.00
# Customer 1 enters call at 0.00
# Customer 2 enters call at 0.00
# Customer 7 enters waiting queue at 1.00
# Customer 8 enters waiting queue at 2.00
# Support finished for 1 at 3.74
# Customer 3 enters call at 3.74
# Customer 9 enters waiting queue at 4.00
# Support finished for 2 at 4.51
# Customer 4 enters call at 4.51
# Support finished for 3 at 4.74
# Customer 5 enters call at 4.74
# Support finished for 5 at 5.74
# Customer 7 enters call at 5.74
# Customer 10 enters waiting queue at 6.00
# Support finished for 7 at 8.44
# Customer 8 enters call at 8.44
# Support finished for 4 at 8.56
# Customer 9 enters call at 8.56
# Customer 11 enters waiting queue at 9.00
# Customer 12 enters waiting queue at 10.00
# Customer 13 enters waiting queue at 12.00
# Customer 14 enters waiting queue at 14.00
# Support finished for 9 at 15.56
# Customer 10 enters call at 15.56
# Support finished for 8 at 15.83
# Customer 11 enters call at 15.83
# Support finished for 11 at 16.83
# Customer 12 enters call at 16.83
# Customer 15 enters waiting queue at 17.00
# Customer 16 enters waiting queue at 19.00
# Support finished for 12 at 19.63
# Customer 13 enters call at 19.63
# Support finished for 13 at 20.63
# Customer 14 enters call at 20.63
# Support finished for 14 at 21.63
# Customer 15 enters call at 21.63
# Customer 17 enters waiting queue at 22.00
# Customer 18 enters waiting queue at 23.00
# Support finished for 10 at 23.67
# Customer 16 enters call at 23.67
# Customer 19 enters waiting queue at 26.00
# Support finished for 15 at 28.55
# Customer 17 enters call at 28.55
# Customer 20 enters waiting queue at 29.00
# Support finished for 17 at 29.55
# Customer 18 enters call at 29.55
# Customer 21 enters waiting queue at 30.00
# Support finished for 16 at 30.75
# Customer 19 enters call at 30.75
# Support finished for 18 at 30.81
# Customer 20 enters call at 30.81
# Customer 22 enters waiting queue at 31.00
# Support finished for 19 at 32.59
# Customer 21 enters call at 32.59
# Customer 23 enters waiting queue at 33.00
# Customer 24 enters waiting queue at 35.00
# Customer 25 enters waiting queue at 36.00
# Support finished for 21 at 36.68
# Customer 22 enters call at 36.68
# Customer 26 enters waiting queue at 38.00
# Support finished for 22 at 38.12
# Customer 23 enters call at 38.12
# Customer 27 enters waiting queue at 39.00
# Customer 28 enters waiting queue at 42.00
# Customer 29 enters waiting queue at 43.00
# Support finished for 20 at 43.15
# Customer 24 enters call at 43.15
# Customer 30 enters waiting queue at 44.00
# Customer 31 enters waiting queue at 46.00
# Support finished for 24 at 46.52
# Customer 25 enters call at 46.52
# Support finished for 23 at 47.18
# Customer 26 enters call at 47.18
# Support finished for 25 at 47.52
# Customer 27 enters call at 47.52
# Customer 32 enters waiting queue at 49.00
# Support finished for 27 at 50.68
# Customer 28 enters call at 50.68
# Customer 33 enters waiting queue at 51.00
# Support finished for 28 at 51.68
# Customer 29 enters call at 51.68
# Support finished for 26 at 53.97
# Customer 30 enters call at 53.97
# Customer 34 enters waiting queue at 54.00
# Support finished for 29 at 55.34
# Customer 31 enters call at 55.34
# Customer 35 enters waiting queue at 56.00
# Customer 36 enters waiting queue at 57.00
# Customer 37 enters waiting queue at 59.00
# Customer 38 enters waiting queue at 62.00
# Support finished for 31 at 63.53
# Customer 32 enters call at 63.53
# Customer 39 enters waiting queue at 64.00
# Support finished for 32 at 64.53
# Customer 33 enters call at 64.53
# Customer 40 enters waiting queue at 66.00
# Support finished for 30 at 67.93
# Customer 34 enters call at 67.93
# Customer 41 enters waiting queue at 69.00
# Support finished for 33 at 69.32
# Customer 35 enters call at 69.32
# Customer 42 enters waiting queue at 72.00
# Customer 43 enters waiting queue at 73.00
# Support finished for 35 at 75.03
# Customer 36 enters call at 75.03
# Support finished for 34 at 75.92
# Customer 37 enters call at 75.92
# Customer 44 enters waiting queue at 76.00
# Support finished for 36 at 76.03
# Customer 38 enters call at 76.03
# Support finished for 38 at 77.03
# Customer 39 enters call at 77.03
# Support finished for 39 at 78.70
# Customer 40 enters call at 78.70
# Customer 45 enters waiting queue at 79.00
# Support finished for 40 at 80.67
# Customer 41 enters call at 80.67
# Customer 46 enters waiting queue at 82.00
# Customer 47 enters waiting queue at 85.00
# Customer 48 enters waiting queue at 86.00
# Support finished for 37 at 87.26
# Customer 42 enters call at 87.26
# Customer 49 enters waiting queue at 89.00
# Support finished for 41 at 89.27
# Customer 43 enters call at 89.27
# Support finished for 42 at 89.76
# Customer 44 enters call at 89.76
# Customer 50 enters waiting queue at 92.00
# Support finished for 43 at 93.29
# Customer 45 enters call at 93.29
# Customer 51 enters waiting queue at 94.00
# Customer 52 enters waiting queue at 95.00
# Support finished for 44 at 95.80
# Customer 46 enters call at 95.80
# Customer 53 enters waiting queue at 96.00
# Support finished for 46 at 96.80
# Customer 47 enters call at 96.80
# Support finished for 47 at 97.80
# Customer 48 enters call at 97.80
# Customer 54 enters waiting queue at 98.00
# Support finished for 45 at 99.29
# Customer 49 enters call at 99.29
# Customer 55 enters waiting queue at 101.00
# Customer 56 enters waiting queue at 103.00
# Support finished for 48 at 104.30
# Customer 50 enters call at 104.30
# Customer 57 enters waiting queue at 106.00
# Customer 58 enters waiting queue at 108.00
# Support finished for 50 at 109.72
# Customer 51 enters call at 109.72
# Customer 59 enters waiting queue at 110.00
# Customer 60 enters waiting queue at 113.00
# Support finished for 49 at 113.01
# Customer 52 enters call at 113.01
# Customer 61 enters waiting queue at 116.00
# Support finished for 52 at 117.96
# Customer 53 enters call at 117.96
# Customer 62 enters waiting queue at 119.00
# Support finished for 51 at 119.25
# Customer 54 enters call at 119.25
# Customes handled: 51
